# %% [markdown]
# # Web Scraping With The Pandas

# %%
import os
import pandas as pd

# %%
data_laliga22 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/SP1.csv') #reading csv file

# %%
data_laliga22
# Out:
#      Div        Date   Time    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    SP1  12/08/2022  20:00     Osasuna     Sevilla     2     1   H     1
# 1    SP1  13/08/2022  16:00       Celta     Espanol     2     2   D     1
# 2    SP1  13/08/2022  18:00  Valladolid  Villarreal     0     3   A     0
# 3    SP1  13/08/2022  20:00   Barcelona   Vallecano     0     0   D     0
# 4    SP1  14/08/2022  16:30       Cadiz    Sociedad     0     1   A     0
# ..   ...         ...    ...         ...         ...   ...   ...  ..   ...
# 375  SP1  04/06/2023  20:00       Betis    Valencia     1     1   D     1
# 376  SP1  04/06/2023  20:00       Celta   Barcelona     2     1   H     1
# 377  SP1  04/06/2023  20:00       Elche       Cadiz     1     1   D     0
# 378  SP1  04/06/2023  20:00     Espanol     Almeria     3     3   D     1
# 379  SP1  04/06/2023  20:00  Valladolid      Getafe     0     0   D     0
#
#      HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# ...

# %%
data_laliga22 = data_laliga22.rename(columns={'Date': 'date',
                                            'HomeTeam': 'home_team',
                                            'AwayTeam': 'away_team',
                                            'FTHG': 'home_goals',
                                            'FTAG': 'away_goals'})

# %%
data_laliga22
# Out:
#      Div        date   Time   home_team   away_team  home_goals  away_goals  \
# 0    SP1  12/08/2022  20:00     Osasuna     Sevilla           2           1
# 1    SP1  13/08/2022  16:00       Celta     Espanol           2           2
# 2    SP1  13/08/2022  18:00  Valladolid  Villarreal           0           3
# 3    SP1  13/08/2022  20:00   Barcelona   Vallecano           0           0
# 4    SP1  14/08/2022  16:30       Cadiz    Sociedad           0           1
# ..   ...         ...    ...         ...         ...         ...         ...
# 375  SP1  04/06/2023  20:00       Betis    Valencia           1           1
# 376  SP1  04/06/2023  20:00       Celta   Barcelona           2           1
# 377  SP1  04/06/2023  20:00       Elche       Cadiz           1           1
# 378  SP1  04/06/2023  20:00     Espanol     Almeria           3           3
# 379  SP1  04/06/2023  20:00  Valladolid      Getafe           0           0
#
# ...
